# %%
from openai import OpenAI
from PIL import Image
# from dotenv import load_dotenv
from dotenv import dotenv_values
config = dotenv_values('../.env')


def generate_dataset():

    prompt = """
            You are an expert at extracting useful information from user queries. I need you to generate one query-information pair. The query is based on user's needs to retrieve relevant files with date or content information.
            If the user does not specify the date. Use relative number. "date_sort" means the order of sorting files. 1 means sorting files in descending order to get the oldest file. 0 means no sorting. -1 means getting the newest file. 
            "video_hour" indicates hour,"video_minute" indicates minute. Additionally, please generate 5 synonyms for the extracted 'file content'. 
            The extracted information should exclusively contain key-value pairs in JSON format.  Since users are from various domains, the data should be as diverse as possible in terms of specific or unsepcific file date, file date sorting information, video duration.
            You should only use the keys cantained in the examples. Below are 10 examples that meet these requirements:

            Example1
            ### query: Find the latest presentations on E-Commerce strategies, created in April 2022
            ### information:{"date_year":[2022,2022],"date_month":[4,4],"date_day":[0,0],"date_sort":-1,"file_content":["E-Commerce Strategy Deck","Online Marketing Presentation","Digital Commerce Report"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}

            Example2
            ### query: Find the oldest videos related to space exploration with a duration of less than 10 minutes
            ### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[0, 10]}

            Example2
            ### query: Find the newest videos about space exploration, longer than 30 minutes long
            ### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[30, 0]}

            Example3
            ### Find my photos from New York last summer
            ### information: {"date_year":[-1,-1],"date_month":[6,8],"date_day":[0,0],"date_sort":0,"file_content":["Photo taken in New York","New York Image","New York Snapshot","New York Picture","New York Photograph"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}

            Example4
            ### query: Find the latest articles on artificial intelligence
            ### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["AI Research Article","Machine Learning Paper","Deep Learning Study"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}

            Example5
            ### query: Newest educational videos, 10 to 20 minutes long, on quantum physics
            ### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Quantum Physics Tutorial","Particle Physics Lecture","Quantum Mechanics Explanation"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[10, 20]}

            Example6
            ### query: Find the latest podcasts on personal finance, released between January 2022 and March 2022.
            ### information: {"date_year":[2022,2022],"date_month":[1,3],"date_day":[0,0],"date_sort":-1,"file_content":["Personal Finance Podcast","Investment Tips Audio","Budgeting Advice Episode"],"file_type":["mp3"],"video_hour":[], "video_minute":[]}

            Example7
            ### query: Find any file on cat breeds downloaded before August 29th, 2022
            ### information: {"date_year":[0,2022],"date_month":[0,8],"date_day":[0,29],"date_sort":0,"file_content":["Cat Breeds File","Feline Information Document","Pet Encyclopedia"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}

            Example8
            ### query: Show me all files related to machine learning downloaded after September 15th, 2021.
            ### information: {"date_year":[2021,0],"date_month":[9,0],"date_day":[15,0],"date_sort":0,"file_content":["Machine Learning File","AI Research Paper","Deep Learning Document"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}

            Example9
            ### query: Find the newest photos from last week's family trip to the zoo
            ### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-7, 0],"date_sort":-1,"file_content":["Zoo Photos","Family Outing Pictures","Animal Snapshots","Zoo Memories"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}

            Example10
            ### query: Find the oldest marketing presentations created in the last year with "digital" in the content
            ### information: {"date_year":[-1, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Digital Marketing Presentation","Online Marketing Deck","E-Commerce Strategy Report"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}
            """

    import google.generativeai as genai

    GOOGLE_API_KEY = "AIzaSyBZYh96jEmTRXJt_fGWlxtZkfd5maZbmZY"
    genai.configure(api_key=GOOGLE_API_KEY)

    # Using Gemini API
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt)
    query_tasks = response.candidates[0].content.parts[0].text
    return query_tasks

response = []
for i in range(1000):
    print(len(response))
    response.append(generate_dataset())
# Out:
# 0

# %%
response
# Out:
# ['### query: Find videos about fashion shows released yesterday\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-1, 0],"date_sort":0,"file_content":["Fashion Show Video","Catwalk Footage","Model Interview"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the files containing "strategy" in the file name with any date\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Strategy File","Strategic Plan","Business Strategy Report"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest videos on yoga longer than 15 minutes, downloaded in the last month\n### information: {"date_year":[0,0],"date_month":[-1,0],"date_day":[0,0],"date_sort":-1,"file_content":["Yoga Tutorial","Yoga Workout","Meditation Video"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[15, 0]}\n\n### Synonyms for file content:\n- content\n- text\n- data\n- information\n- document',
#  '### query: Find the newest sales reports for the year 2023, over 5 minutes long\n### information: {"date_year":[2023,2023],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Sales Report","Quarterly Performance Analysis","Revenue Forecast"],"file_type":["pdf","xls","xlsx"],"video_hour":[], "video_minute":[5, 0]}',
#  '### query: Find the latest videos about deep learning, longer than 20 minutes long, released after March 18th, 2022\n### information: {"date_year":[2022,0],"date_month":[3,0],"date_day":[18,0],"date_sort":-1,"file_content":["Deep Learning Video","Machine Learning Tutorial","Neural Networks Lecture"],"file_type":["mp4","mov"],"video_hour":[0, 20]}',
#  '### query: Find the latest marketing presentations with a video duration shorter than 10 minutes\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Marketing Presentation","Sales Pitch Video","Product Demo Recording"],"file_type":["ppt","pptx","mp4","mov"],"video_hour":[], "video_minute":[0,10]}',
#  '### query: Find any videos on the history of the internet published in 2021 \n### information: {"date_year":[2021, 2021],"date_month":[0,0],"date_day":[0,0], "date_sort": 0, "file_content": ["History of the Internet","Web Evolution","Internet Growth"],"file_type": ["mp4", "mov", "avi"],"video_hour":[], "video_minute":[]}\n\n',
#  '### query: Show me any file that has the word \'marketing\' in it and created within the past year\n### information: {"date_year":[-1, 0],"date_month":[0,0],"date_day":[0,0], "date_sort":0,"file_content":["Marketing Plan","Marketing Research Report","Marketing Strategy Deck"],"file_type":["pdf","docx","ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest files on quantum computing released after October 2021\n### information: {"date_year":[2021,0],"date_month":[10,0],"date_day":[0,0],"date_sort":-1,"file_content":["Quantum Computing Article","Quantum Mechanics Paper","Qubits And Entanglement Tutorial"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest photos of my cats\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["cat pictures","feline photos","animal snapshots","pet images"],"file_type":["jpg","jpeg","heif","png","tiff"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me all files about digital marketing.\n### information: {"date_year":[], "date_month":[], "date_day":[], "date_sort":0, "file_content":["digital marketing", "online marketing", "internet marketing", "social media marketing", "email marketing"], "file_type":[], "video_hour":[], "video_minute":[]}',
#  '### query: Find the latest documents on finance downloaded in the last two months\n### information: {"date_year":[-2, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Finance Document","Investment Report","Budgeting File"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find all photos that mention travel experiences in June 2024\n### information: {"date_year":[2024,2024],"date_month":[6,6],"date_day":[0,0],"date_sort":0,"file_content":["Travelogue","Vacation Pictures","Adventure Photos","Journey Snapshots"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest articles about AI published in 2022\n### information: {"date_year":[2022,2022],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["AI Research Article","Machine Learning Paper","Deep Learning Study"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the most up-to-date report on climate-change\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Climate-change Report","Global Warming Study","Environmental Impact Analysis"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest medical research papers on cancer diagnosis, downloaded in the past 6 months.\n### information: {"date_year":[0,0],"date_month":[-6,0],"date_day":[0,0],"date_sort":-1,"file_content":["Cancer Diagnosis Research","Oncology Report","Medical Imaging Analysis"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest podcasts on personal finance, released after October 2022.\n### information: {"date_year":[2022,0],"date_month":[10,0],"date_day":[0,0],"date_sort":-1,"file_content":["Personal Finance Podcast","Investment Tips Audio","Budgeting Advice Episode"],"file_type":["mp3"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me any documents about climate change, downloaded or modified within the past month.\n### information: {"date_year":[0,0],"date_month":[-1,0],"date_day":[0,0],"date_sort":0,"file_content":["IPCC Report","Climate Change Analysis","Environmental Assessment"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest videos about space exploration, longer than 30 minutes long\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[0, 30]}\n### synonyms for file_content: video content, video subject, video topic, video theme, video information',
#  '### query: Any files on quantum computing or machine learning downloaded after December 24th, 2021.\n### information: {"date_year":[2021,0],"date_month":[12,0],"date_day":[24,0],"date_sort":0,"file_content":["Quantum Computing File","Machine Learning Document", "Quantum Physics Paper"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me all research videos released within the last 2 months, on cancer biology. \n### information: {"date_year":[0,0],"date_month":[-2,0],"date_day":[0,0],"date_sort":0,"file_content":["Cancer Biology Research","Cancer Treatment Study","Oncology Video"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}',
#  '### query: Find all podcast episodes on quantum computing more than 2 hours long that were published in 2022\n### information: {"date_year":[2022,2022],"date_month":[0, 0],"date_day":[0, 0],"date_sort":0,"file_content":["Quantum Computing Podcast","Quantum Technologies Audio","Quantum Physics Episode"],"file_type":["mp3"],"video_hour":[2,0], "video_minute":[0,0]}',
#  '### query: Find the newest 2 videos on climate change, longer than 35 minutes long\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Climate Change Documentary","Environmental Impact Report","Global Warming Footage"],"file_type":["mp4","mov"],"video_hour":[0,35], "video_minute":[0, 0]}\n\nSynonyms for \'file content\':\n- subject\n- topic\n- theme\n- thesis\n- material',
#  '### query: Get the latest 20 CVs received last week\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-7, -7],"date_sort":-1,"file_content":["CV","Resume","Job Application","Personal Profile"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest articles on quantum computing released in the last 6 months\n### information: {"date_year":[0,0],"date_month":[-6, 0],"date_day":[0,0],"date_sort":-1,"file_content":["Quantum Computing Article","Qubits and Algorithms Paper"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest 3 videos related to electric vehicles, uploaded before yesterday\n### information: {"date_year":[0, 0], "date_month":[0, 0], "date_day":[0, -1], "date_sort":1, "file_content":["Electric Vehicle Video","Renewable Energy Documentary", "Zero Emission Technology Report"], "file_type":["mp4", "mov"], "video_hour":[], "video_minute":[]}',
#  '### query: Show me any document on climate change created within the past two years\n### information: {"date_year":[-2, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Climate Change Report","Global Warming Analysis","Environmental Impact Study"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find my photos taken during our San Francisco trip last year, sorted by date\n### information: {"date_year":[-1, -1],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["San Francisco Trip Photos","Golden Gate Bridge Snapshots","Alcatraz Images","Fisherman\'s Wharf Pictures"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}\n\n### Synonyms for file content:\n- content\n- text\n- data\n- information\n- material',
#  '### query: Find the Youtube videos from 2021 with durations between 30 minutes and 60 minutes.\n### information: {"date_year":[2021, 2021],"date_month":[0, 0],"date_day":[0, 0],"date_sort":0,"file_content":["Youtube Video","Clips","Recordings"],"file_type":["mp4", "mov"],"video_hour":[0, 1],"video_minute":[30, 0]}',
#  '### query: Find the latest files about gardening released in the last 2 months.\n### information: {"date_year":[0,0],"date_month":[-2, 0],"date_day":[0,0],"date_sort":-1,"file_content":["Gardening Guide","Plant Care Instructions","Landscaping Design"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find marketing files on SEO since 2020\n### information: {"date_year":[2020, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["SEO Best Practices","Search Engine Optimization Guide","SEO for Beginners"],"file_type":["pdf","pptx","docx"],"video_hour":[], "video_minute":[]}',
#  '### query: Get PDF documents on the topic of education\n### information: {"date_year":[],"date_month":[],"date_day":[],"date_sort":0,"file_content":["education","study","learning","knowledge","teaching"],"file_type":["pdf"],"video_hour":[], "video_minute":[]}',
#  '### query: Find any excel files on "Financial planning" created more than 10 years ago\n### information: {"date_year":[-10, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Financial Planning.xlsx","Budgeting Guide.xlsx","Investment Strategies.xlsx"],"file_type":["xlsx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest videos related to space exploration, uploaded in the last 2 months, with a duration of less than 20 minutes\n### information: {"date_year":[0,0],"date_month":[-2, 0],"date_day":[0, 0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[0, 20]}',
#  '### query: Find the most recent biology videos, sorted by oldest to newest\n### information:  {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Biology Lecture","Science Documentary"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}',
#  '### query: Find all documents on resume writing released this year, longer than 1500 words\n### information: {"date_year":[2023,2023],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Resume Writing Guide","CV Tips Document","Job Application Advice"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find all files with AI in the content, sorted by oldest to newest.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["AI Research","Artificial Intelligence Document","Machine Learning Notes"],"file_type":["docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest videos, less than 10 minutes long,related to space exploration\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[0, 10]}',
#  '### query: Find the latest videos on astrophysics with a duration of less than 30 minutes\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Astrophysics Lecture","Cosmology Video","Space Science Documentary"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[0, 30]}',
#  '### query: Find the most up-to-date presentations on online business strategy that were produced in October 2022.\n### information:{"date_year":[2022,2022],"date_month":[10,10],"date_day":[0,0],"date_sort":-1,"file_content":["Online Business Strategy Deck","E-Commerce Presentation","Digital Marketing Report"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest photos related to gardening\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Gardening Photos","Plant Images","Outdoor Landscaping","Horticulture Snapshots"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}\n',
#  '### query: Show me the most recent video uploaded by Dr. Smith about Particle Physics.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Particle Physics Video","Lecture by Dr. Smith","Quantum Mechanics Explanation"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[]}',
#  '### query: Find any files downloaded before December 12th, 2022\n### information: {"date_year":[0,2022],"date_month":[0,12],"date_day":[0,12],"date_sort":0,"file_content":[],"file_type":[],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest videos on quantum physics, released in this year, longer than 45 minutes long, with "particle" in the content\n### information: {"date_year":[0,-1],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Particle Physics Video","Quantum Physics Lecture","Quantum Mechanics Explanation"],"file_type":["mp4","avi"],"video_hour":[0,45], "video_minute":[0,0]}',
#  '### query: Find all my files about gardening created before 2022\n### information: {"date_year":[-1,2022],"date_month":[0,0],"date_day":[0, 0],"date_sort":0,"file_content":["Gardening Tips Sheet","Plant Care Guide","Horticulture Journal"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '            ### query: Find the latest videos about space exploration, at least 60 minutes long, released in the last 30 days.\n            ### information: {"date_year":[0, 0],"date_month":[0, 0],"date_day":[0, 30],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[1, 0],"video_minute":[0, 0]}',
#  '### query: Find the oldest file content with "music" in its title created in November 2021\n### information: {"date_year": [2021, 2021], "date_month": [11, 11], "date_day": [0, 0], "date_sort": 1, "file_content": ["Music Collection", "Song Compilation", "Music Album", "Music Archive", "Music Library"], "file_type": [], "video_hour": [], "video_minute": []}',
#  '### query: Find the latest pdfs on onboarding new employees\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Employee Onboarding Guide","New Hire Training Manual","Welcome to the Team Presentation"],"file_type":["pdf"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest marketing presentation that contains "E-Commerce" in the content.\n### information: {"date_year":[],"date_month":[],"date_day":[],"date_sort":-1,"file_content":["E-Commerce Presentation","Online Marketing Presentation","Digital Commerce Report","Marketing Strategy Deck"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest videos about gravity, created in July 2023, longer than 20 minutes long\n### information: {"date_year":[2023,2023],"date_month":[7,7],"date_day":[0,0],"date_sort":-1,"file_content":["Gravity Video","Physics Documentary","Scientific Explanation"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[20, 0]}',
#  '### query: Find any recent videos about basketball with a duration of more than 30 minutes\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Basketball Game Footage","NBA Highlights","Basketball Tutorial"],"file_type":["mp4","mov"],"video_hour":[0,30], "video_minute":[]}',
#  '### query: Find files on climate change created in the past 2 months, longer than 30 minutes long\n### information: {"date_year":[0, 0], "date_month":[-2,0], "date_day":[0, 0], "date_sort": 0, "file_content":["Climate Change Documentary", "Environmental Impact Video", "Global Warming Footage"],"file_type":["mp4","mov"],"video_hour":[0,30], "video_minute":[0,0]}\n\n#### Synonyms for \'file content\':\n* file subject\n* file topic\n* file theme\n* file matter\n* file issue',
#  '### query: Find all pdfs about digital marketing published in October 2022\n### information: {"date_year":[2022],"date_month":[10],"date_day":[0],"date_sort":0,"file_content":["Digital Marketing Trends","Social Media Marketing Guide","Online Advertisement Report"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest podcasts on marketing, published in June 2021\n### information: {"date_year":[2021,2021],"date_month":[6,6],"date_day":[0,0],"date_sort":-1,"file_content":["Marketing Podcast","Business Marketing Audio","Digital Marketing Advice Episode"],"file_type":["mp3"],"video_hour":[], "video_minute":[]}\n\n### Synonyms of \'file content\':\n1. file information\n2. file subject\n3. file context\n4. file topic\n5. file substance',
#  '### query: Find the newest videos about space exploration, no longer than 1 hour\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[0,1], "video_minute":[0,0]}\n\n### Synonyms for \'file content\':\n \'content\', \'text\', \'subject\', \'topic\', \'theme\'',
#  '### query: Find my project files on deep learning that I downloaded in the first quarter of this year\n### information: {"date_year":[2023,2023],"date_month":[1,3],"date_day":[0,0],"date_sort":0,"file_content":["Deep Learning Files","AI Research Paper","Machine Learning Document"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest 20-minute whiteboard animation videos about artificial intelligence\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["AI Whiteboard Animation","Machine Learning Explainer Video","Deep Learning Tutorial"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[0, 20]}\n\n### Synonyms for "file_content"\n* data\n* information\n* context\n* subject\n* material',
#  '### query: Retrieve the oldest podcasts on climate change from the past 3 months\n### information: {"date_year":[0,0],"date_month":[-3,0],"date_day":[0,0],"date_sort":1,"file_content":["Climate Change Podcast","Environmental Audio","Sustainability Interview"],"file_type":["mp3"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest articles on artificial intelligence, published within the last three months.\n### information: {"date_year:[0,0],"date_month":[-3,0],"date_day":[0,0],"date_sort":-1,"file_content":["AI Research Article","Machine Learning Paper","Deep Learning Study"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}\n\n### query: Find any videos with “Paris” in the title, longer than 1 hour.\n### information: {"date_year:[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Paris Travel Vlog","Paris City Guide","Parisian Adventure"],"file_type":["mp4","mov"],"video_hour":[1,0],"video_minute":[0,0]}\n\n### query: Find all files containing videos related to baking, sorted from newest to oldest.\n### information: {"date_year:[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Baking Tutorial","Cake Decorating Demo","Cookie Recipes"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}\n\n### query: Find the latest web design portfolio created in the last six months.\n### information: {"date_year:[0,0],"date_month":[-6,0],"date_day":[0,0],"date_sort":-1,"file_content":["Web Design Portfolio","UI/UX Design Showcase","Creative Website Examples"],"file_type":["html","css","js"],"video_hour":[], "video_minute":[]}\n\n### query: Find any files on fitness, downloaded within the last year.\n### information: {"date_year":[-1,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Fitness Guide","Workout Plan","Nutrition Tips"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}\n\n### Synonyms for \'file content\':\n- file topic\n- file subject\n- file theme\n- file matter\n- file domain',
#  '### query: Find the oldest English training videos created before July 20th, 2023 that are longer than 25 minutes\n### information: {"date_year":[0,2023],"date_month":[0,7],"date_day":[0,20],"date_sort":1,"file_content":["English Training Video","Language Learning Tutorial","Grammar Lesson","Pronunciation Guide"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[25, 0]}',
#  '### query: Find me all files downloaded between May 2021 and January 2022 that include the word "music" or "song" in the content, and are no longer than 4 minutes long\n### information: {"date_year":[2021,2022],"date_month":[5,1],"date_day":[0,0],"date_sort":0,"file_content":["Music File","Song Download","Audio Clip","New Track Release"],"file_type":["mp3","wav"],"video_hour":[], "video_minute":[0,4]}',
#  '### query: Find the newest sprint plan which includes the substr "deployment" and was last updated in the last 3 months\n### information: {"date_year":[-3,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["sprint plan","deployment plan"],"file_type":["docx","pdf",".txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me the newest videos about space exploration, longer than 25 minutes long\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[0, 25],"video_minute":[]}',
#  '### query: Find the newest articles on COVID-19 vaccines published in the last 30 days.\n### information: {"date_year":[-1,0],"date_month":[-1,0],"date_day":[-30,0],"date_sort":-1,"file_content":["COVID-19 Vaccine Article","Vaccination Research Paper","Immunology Report"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find me all files related to digital marketing with more than 5 pages and downloaded within the last 2 days\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-2, -1],"date_sort":0,"file_content":["Digital Marketing File","Online Promotion Document","E-Commerce Strategy Document"],"file_type":["pdf","doc","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest documents about space exploration downloaded in the past 6 months\n### information: {"date_year":[0,0],"date_month":[-6,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Document","Astronomy Report","NASA Information"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest any file on "hiking" downloaded in the last 60 days\n### information: {"date_year":[0, 0],"date_month":[0, 0],"date_day":[-60, 0],"date_sort":-1,"file_content":["Hiking Guide","Trail Map","Trekking Information"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}\n\nSynonyms for \'file content\':\n- file_content\n- file_data\n- file_subject\n- file_text\n- file_topic',
#  '### query: Find the latest video tutorials related to app development released after June 30th 2022\n### information: {"date_year":[2022, 0],"date_month":[6, 0],"date_day":[30, 0],"date_sort":-1,"file_content":["App Development Tutorial", "Coding Lesson", "Programming Guide"],"file_type":["mp4"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest research papers on climate change from the past 2 months\n### information: {"date_year":[0,0],"date_month":[-2,0],"date_day":[0,0],"date_sort":-1,"file_content":["Climate Change Research Paper","Environmental Impact Report","Sustainability Analysis"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}\n\nSynonyms for \'file content\':\n- content\n- subject\n- topic\n- theme\n- information',
#  '### query: What are the oldest videos about cats more than 10 minutes long\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Cat Video","Feline Documentary","Pet Footage"],"file_type":["mp4","mov"],"video_hour":[0,10]}',
#  '### query: Show me my math homework from last week.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-7, 0],"date_sort":0,"file_content":["Math Homework","Algebra Notes","Calculus Sheet"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me the latest videos about AI research, longer than 20 minutes long and created within the last 6 months.\n### information: {"date_year":[0,-1],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["AI Research Video","Machine Learning Tutorial","Deep Learning Lecture"],"file_type":["mp4","mov"],"video_hour":[0,20], "video_minute":[]}\n\n### Synonyms for \'file content\':\n- Document Contents\n- File Contents\n- Text Contents\n- Information in File\n- Data in File',
#  '### query: Find the oldest video tutorials longer than 1 hour and 20 minutes on cloud computing\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["Cloud Computing Tutorial","Cloud Architecture Guide","Software as a Service Guide"],"file_type":["mp4","mov"],"video_hour":[1,20]}',
#  '### query: Find the newest 5 minutes long educational videos on molecular biology\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Molecular Biology Tutorial","Cell Biology Lecture","Genetics Explanation"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[0, 5]}',
#  '### query: Find the newest finance videos uploaded in the last 60 days\n### information: {"date_year":[0, 0],"date_month":[0, 0],"date_day":[-60, 0],"date_sort":-1,"file_content":["Finance Video","Investment Advice Tutorial","Financial Planning Series"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}\n\n### Synonyms for \'file content\':\n- file subject\n- content topic\n- text\n- file matter\n- document context',
#  '### query: Find all files that are related to designs that I have downloaded in the last 6 months\n### information: {"date_year":[0,0],"date_month":[-6,0],"date_day":[0,0],"date_sort":0,"file_content":["Design File","Art Resource","Creative Document"],"file_type":["pdf","docx","txt", "jpg", "psd"],"video_hour":[], "video_minute":[]}\n\n**Synonyms for \'file content\':**\n* content\n* data\n* information\n* data \n* subject matter',
#  '### query: Find me the oldest PPTs with "E-commerce Strategy" in the content, created before March 8th, 2022.\n### information: {"date_year":[0,2022],"date_month":[0,3],"date_day":[0,8],"date_sort":1,"file_content":["E-commerce strategy","Online shopping presentation","Digital marketing slides"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find me any files about basketball downloaded before June 2022\n### information: {"date_year":[0,2022],"date_month":[0,6],"date_day":[0,0],"date_sort":0,"file_content":["Basketball File","NBA News Article","Game Stats Report"],"file_type":["pdf","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest presentations on digital marketing strategies\n### information: {"date_year":[0, 0],"date_month":[0, 0],"date_day":[0, 0],"date_sort":1,"file_content":["Digital Marketing Presentation","Online Marketing Deck","E-commerce Strategy Report","Digital Marketing Portfolio","Web Analytics Report"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Show me the newest file created in the last year with the word "project" or "plan" in the content and the file type is ppt\n### information: {"date_year":[-1, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["project management plan","product roadmap", "business proposal", "project presentation"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest videos uploaded before 4 pm yesterday on the topic of climate change, more than 1 hour.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-1,-1],"date_sort":-1,"file_content":["Climate Change Video","Environmental Documentary","Global Warming Footage"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[1, 0]}',
#  '### query: Find the latest 1-hour videos on theoretical physics released in the last 3 months\n### information: {"date_year":[0,0],"date_month":[-3,0],"date_day":[0,0],"date_sort":-1,"file_content":["Theoretical Physics Video","Quantum Mechanics Lecture","Relativity Theory Explanation"],"file_type":["mp4","avi"],"video_hour":[1,1],"video_minute":[0,0]}',
#  '### query: Find any sales report from last year, in a PDF format\n### information: {"date_year":[-1, 0],"date_month":[0, 0],"date_day":[0, 0],"date_sort":0,"file_content":["Sales Report","Sales Figures","Revenue Analysis"],"file_type":["pdf"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the most recent sales reports created in the last quarter of 2022 \n### information: {"date_year":[2022,2022],"date_month":[10,12],"date_day":[1,0],"date_sort":-1,"file_content":["Sales Report","Revenue Analysis","Quarterly Earnings"],"file_type":["pdf","xlsx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest videos about space exploration, longer than 30 minutes long\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mp4","mov"],"video_hour":[0, 30]}',
#  '### query: Get me the latest files about quantum computing, downloaded earlier this year.\n### information: {"date_year":[2023,2023],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Quantum Computing","Quantum Mechanics","Quantum Algorithms"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: I need any videos longer than 10 minutes, related to quantum computing\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Quantum Computing Video","Quantum Mechanics Explained","Qubits and Quantum Algorithms"],"file_type":["mp4","mov"],"video_hour":[0,10]}',
#  '### query: Find me some old user manuals that I saved in September 2021 about reservation policies\n            ### information: {"date_year":[2021, 2021],"date_month":[9,9],"date_day":[0,0],"date_sort":1,"file_content":["User Manual", "User Guide", "Instruction Manual", "Policy Document", "Regulation Guide"],"file_type":["pdf","doc","docx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the most recent medical conference video with a length between 30 and 50 minutes\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Medical Conference Video","Healthcare Symposium Footage","Medical Presentation Recording"],"file_type":["mp4","mov"],"video_hour":[0, 1],"video_minute":[30, 50]}',
#  '### query: Find the newest videos on space exploration, with content containing \'nasa\'\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","NASA Footage","Astronomy Documentary"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest 2 videos related to space exploration uploaded in the last 2 months, longer than 20 minutes\n### information: {"date_year":[0, 0],"date_month":[-2, 0],"date_day":[0,0],"date_sort":-1,"file_content":["Space Exploration Video","Astronomy Documentary","NASA Footage"],"file_type":["mov","mp4"],"video_hour":[0,20], "video_minute":[0,0]}\n\n### Synonyms for \'file content\':\n1. subject matter\n2. topic\n3. theme\n4. argument\n5. discourse',
#  '### query: Show me all the newest music files that are longer than 15 minutes\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["music"],"file_type":["mp3","wav","flac"],"video_hour":[], "video_minute":[15,0]}',
#  '### query: Find all the videos related to cat breeds\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Cat Breeds Video","Feline Information Clip","Pet Encyclopedia Film"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}',
#  '### query: Find me the oldest financial reports longer than 1 hour released in the last 6 months\n### information: {"date_year":[0, 0],"date_month":[-6, 0],"date_day":[0, 0],"date_sort":1,"file_content":["Financial Report","Earnings Call Transcript","Quarterly Results"],"file_type":["pdf","docx","txt"],"video_hour":[1,0], "video_minute":[0, 0]}\n\nSynonyms for \'file content\':\n1. Subject matter\n2. Text\n3. Content\n4. Documents\n5. Information',
#  '### query: how recent has the document been changed that has my resume\n### information: {"date_year":[],"date_month":[],"date_day":[],"date_sort":-1,"file_content":["resume","cv","my resume"],"file_type":["pdf","docx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest financial reports for the third quarter of last year\n### information: {"date_year":[-1, -1], "date_month":[7,9], "date_day":[0,0], "date_sort":-1, "file_content":["Financial Report", "Quarterly Earnings Statement", "Income Statement", "Balance Sheet"], "file_type":["pdf", "xlsx"], "video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest meeting notes created in December 2022 that are longer than 30 minutes.\n### information: {"date_year":[2022,2022],"date_month":[12,12],"date_day":[0,0],"date_sort":1,"file_content":["Meeting Notes","Minutes","Team Discussion"],"file_type":["docx","txt"],"video_hour":[0,0],"video_minute":[30,0]}\n\n### query: Find the newest videos about climate change, shorter than 2 hours long.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Climate Change Documentary","Environmental Impact Video","Global Warming Footage"],"file_type":["mp4","mov"],"video_hour":[],"video_minute":[0,120]}\n\n**Synonyms of \'file content\'**: "text", "subject matter", "data", "information", "content"',
#  '### query: playlist of songs from this week\n### information: {"date_year":[0, 0], "date_month":[0, 0], "date_day": [-7, 0], "date_sort": 0, "file_content":["song","music","audio track"],"file_type":["mp3","wav","m4a"],"video_hour": [], "video_minute": []}',
#  '### query: Show me any pdf documents about particle physics downloaded during April 2022.\n### information: {"date_year":[2022,2022],"date_month":[4,4],"date_day":[0,0],"date_sort":0,"file_content":["Particle Physics Paper","Quantum Mechanics Document","High Energy Physics File"],"file_type":["pdf"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the newest files with "data science" or "machine learning" in the name, sorted by date\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Data Science File","Machine Learning Document","AI Research Paper"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}\n\n### query: Show me the pdf files about E-commerce and SEO in the last 6 months\n### information: {"date_year":[0,0],"date_month":[-6,0],"date_day":[0,0],"date_sort":0,"file_content":["E-commerce and SEO Guide","Online Marketing Strategy"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the most recent medical videos, 10 to 15 minutes long, on genetic diseases\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Genetic Disorders Video","DNA Analysis Tutorial","Mutation Explanation"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[10, 15]}',
#  '### query: Display the latest two podcasts related to gardening released after May 31st, 2022.\n### information: {"date_year":[2022,0],"date_month":[5,0],"date_day":[31,0],"date_sort":-1,"file_content":["Gardening Tips Podcast","Plant Care Audio","Horticulture Advice Episode"],"file_type":["mp3"],"video_hour":[], "video_minute":[]}',
#  '### query: Find old materials on the topic of AI downloaded last fall\n### information: {"date_year":[0,0],"date_month":[9,11],"date_day":[0,0],"date_sort":1,"file_content":["AI Basics","Machine Learning Lecture","Deep Learning Notes"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest budget planning podcasts, longer than 20 minutes long.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Budget Planning Podcast","Financial Advice Audio","Money Management Episode"],"file_type":["mp3"],"video_hour":[], "video_minute":[20, 0]}',
#  '### query: Find any music with a runtime of 15 minutes downloaded in the last 3 days\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-3,0],"date_sort":0,"file_content":["Music File","Audio Download","Song Track"],"file_type":["mp3","wav","aac"],"video_hour":[], "video_minute":[0,15]}',
#  '### query: Help me find the latest 3 videos about "Black Holes" and "Neutron Stars" uploaded to my "Astrophysics" folder and that are shorter than 15 minutes each.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Black Hole Documentary","Neutron Star Exploration","Astrophysics Lecture","Black Holes and Neutron Stars"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[0,15]}',
#  '### query: Find me any files related to the topic of cooking downloaded in the last 2 days\n### information: {"date_year":[-2,-2],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Cooking Guide","Recipe Book","Kitchen Tips"],"file_type":["pdf","docx","txt","jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest documents on artificial intelligence published last year\n### information: {"date_year":[-1, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["AI Research Article","Machine Learning Paper","Deep Learning Study","AI Whitepaper","Artificial Intelligence Report"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find old files about organic farming, could be videos or articles\n### information: {"date_year":[],"date_month":[],"date_day":[],"date_sort":1,"file_content":["Organic Farming Guide","Sustainable Agriculture Article","Natural Farming Tutorial"],"file_type":["pdf","mp4"],"video_hour":[], "video_minute":[]}\n\n### query: Find the newest article, pdf or video on health and nutrition.\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Health and Nutrition Article", "Healthy Eating Guide", "Nutrition Tutorial"],"file_type":["pdf","mp4","docx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the oldest files with "finance" downloaded after April 2021.\n### information: {"date_year":[2021,0],"date_month":[4,0],"date_day":[0,0],"date_sort":1,"file_content":["Finance Documents","Investment Reports","Financial Analysis"],"file_type":["pdf","docx","txt","xls","xlsx"],"video_hour":[], "video_minute":[]}\n\nSynonyms of \'file content\':\n1. file content\n2. file topic\n3. file subject\n4. file data\n5. file information',
#  '### query: Find any file related to dog training, uploaded after January 10th, 2022, within 20 minutes duration.\n### information: {"date_year":[2022,0],"date_month":[1,0],"date_day":[10,0],"date_sort":0,"file_content":["Dog Training Guide","Puppy Obedience Manual","Canine Behavior Notes"],"file_type":["pdf","docx","txt"],"video_hour":[0,0],"video_minute":[0, 20]}',
#  '### query:  Show me the newest marketing presentations created after May 12, 2022 and before August 21, 2022. \n### information: {"date_year":[2022,2022],"date_month":[5,8],"date_day":[12,21],"date_sort":-1,"file_content":["Marketing Presentation","Sales Pitch Deck","Business Proposal"],"file_type":["ppt","pptx"],"video_hour":[], "video_minute":[]}',
#  '### query: Find the latest 5 minutes videos on AI in the last year\n### information: {"date_year":[-1, 0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["AI Video","Machine Learning Tutorial","Deep Learning Explanation"],"file_type":["mp4","avi"],"video_hour":[], "video_minute":[0, 5]}',
#  '### query: Find the newest photos on last Tuesday\'s team outing in San Jose\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[-2, -2],"date_sort":-1,"file_content":["Team Outing Photos","San Jose Memories","Company Event Snapshots","Silicon Valley Pictures"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}\n\n### Definitions of extracted information\n- file_content: the main topics or contents discussed or represented in the file.\n- file_type: the type of file, like presentation (e.g. ppt, pptx); video (e.g. mp4, mov); audio (e.g. mp3); document (e.g. pdf, docx, txt); image (e.g. jpg, jpeg, png, heif, tiff); code (e.g. py, js, java).\n- video_hour: the hour-length of the video content.\n- video_minute: the minute-length of the video content.\n- date_year: the year of the file creation or last modification.\n- date_month: the month of the file creation or last modification.\n- date_day: the day of the file creation or last modification.\n- date_sort: the order of retrieved files. 1 means getting the oldest file. 0 means no sorting. -1 means getting the newest file. ',
#  '### query: Find the oldest documents on a diet with vegetarian recipes\n### information: {"date_year":[0, 0], "date_month":[0, 0], "date_day":[0, 0], "date_sort": 1, "file_content":["Vegetarian Diet Plan", "Plant-Based Recipes", "Vegan Cookbook"], "file_type":["pdf", "docx"], "video_hour":[], "video_minute":[]}\n\n**Synonyms for "file content":**\n - file context\n - file information\n - document content\n - file subject\n - file topic',
#  '### query: Find the latest documents related to "programming" downloaded in the past month\n### information: {"date_year":[0, 0], "date_month":[-1, 0], "date_day":[0, 0], "date_sort":-1, "file_content":["programming guide", "coding tutorial", "software development doc"], "file_type":["pdf", "docx"], "video_hour":[], "video_minute":[]}',
#  '### query: Show me all videos on dinosaurs longer than 1 hour\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Dinosaur Video","Prehistoric Documentary","Natural History Footage"],"file_type":["mp4","mov"],"video_hour":[1,0]}',
#  '### query: Find meeting recordings from last month\n\n### information: {"date_year":[0,0],"date_month":[-1,-1],"date_day":[0,0],"date_sort":0,"file_content":["Meeting Recording","Conference Call Audio","Team Discussion Notes"],"file_type":["mp3","wav"],"video_hour":[], "video_minute":[]}\n\nSynonyms for \'file content\': \n1. subject matter \n2. substance\n3. content \n4. materials \n5. document content',
#  '### query: Find my holiday photos from 2019 in London\n### information: {"date_year":[2019,2019],"date_month":[0,0],"date_day":[0,0],"date_sort":0,"file_content":["Holiday Photos","London Trip Pictures","Travel Snapshots","London Memories"],"file_type":["jpg","jpeg","png","heif","tiff"],"video_hour":[], "video_minute":[]}',
#  '### Query: Find the oldest training materials on AI fundamentals created this year\n### information:{"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":1,"file_content":["AI Fundamentals Training","Machine Learning Basics Tutorial","Deep Learning Introduction"],"file_type":["pdf","docx","txt"],"video_hour":[], "video_minute":[]}',
#  '### query: Find pdf files that are relevant to physics longer than 30 minutes, created in the last two months.\n### information: {"date_year":[0, 0],"date_month":[-2, 0],"date_day":[0, 0],"date_sort":0,"file_content":["physics","quantum","relativity"],"file_type":["pdf"],"video_hour":[0, 0], "video_minute":[30, 0]}',
#  '### query: Find the newest videos of dogs playing\n### information: {"date_year":[0,0],"date_month":[0,0],"date_day":[0,0],"date_sort":-1,"file_content":["Dog Playing Video","Puppy Playing Footage","Pet Funny Moments"],"file_type":["mp4","mov"],"video_hour":[], "video_minute":[]}']

# %%
import json
import re

# # Given string
# input_string = "Task\n### query: Emails regarding my application to Harvard Law School\n### information: {'year': [0, 0],\n                  'month': [0, 0],\n                  'day': [0, 0],\n                  'file content': ['Harvard Law School Application Email', 'Harvard Application Communication', 'Harvard Law Correspondence', 'Harvard Law School Application Conversations', 'Law School Application Email'],\n                  'file type': ['eml', 'msg', 'pdf', 'doc', 'txt']}"


data_list = []

for input_string in response:
    # Extracting relevant information
    query_start = input_string.find("query:")
    query_end = input_string.find("\n### information:")
    query = input_string[query_start + len("query:"):query_end].strip()
    info_start = input_string.find("{")
    info_end = input_string.rfind("}") + 1
    info = input_string[info_start:info_end]

    # Remove spaces between dictionary items while preserving spaces within list items
    info = re.sub(r',\s+', ', ', info)
    # Creating dictionary
    data = {"input": query, "output": info}
    data_list.append(data)


# Saving all dictionaries to a single JSON file
with open("query_v3.json", "a") as json_file:
    json.dump(data_list, json_file, indent=4)
